# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorGryca/filtros_visao_computacional/blob/main/exercicios_limiarizacao_segmentacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercícios de Limiarização e Segmentação
#
# Este notebook contém exercícios práticos para implementar técnicas básicas de limiarização e segmentação de imagens. O foco está em compreender os métodos e em aplicar algoritmos manuais usando NumPy e scikit-image.
#
# ## Objetivos
# - Implementar limiarização global e adaptativa
# - Aplicar Otsu e limiarização multicanal
# - Experimentar segmentação baseada em cor e em regiões
# - Comparar resultados de diferentes abordagens

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import data, color, filters, segmentation, morphology, util

# %matplotlib inline

# Carregar imagens de exemplo
img_gray = data.camera()
img_color = data.astronaut()

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].imshow(img_gray, cmap='gray')
axes[0].set_title('Imagem em Escala de Cinza')
axes[0].axis('off')
axes[1].imshow(img_color)
axes[1].set_title('Imagem Colorida')
axes[1].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Parte 1: Limiarização
#
# ### Exercício 1.1: Limiarização Global
#
# Implemente uma função `global_threshold(image, threshold)` que retorne uma máscara binária aplicando um limiar fixo.
#
# - Valores acima do limiar devem ser 1
# - Valores menores ou iguais devem ser 0

# %%
def global_threshold(image, threshold):
    """
    Limiarização global simples
    """
    # TODO: Implementar limiarização global
    # Dica: use comparação booleana e converta para uint8
    pass

# Exemplo de uso:
# mask = global_threshold(img_gray, 128)
# plt.imshow(mask, cmap='gray')
# plt.title('Limiarização Global')
# plt.axis('off')
# plt.show()

# %% [markdown]
# ### Exercício 1.2: Limiarização Adaptativa
#
# Implemente `adaptive_threshold(image, block_size, c)` usando média local. Cada pixel deve ser comparado ao limiar local calculado na vizinhança.
#
# - `block_size` é o tamanho da vizinhança
# - `c` é um valor subtraído da média local

# %%
def adaptive_threshold(image, block_size, c):
    """
    Limiarização adaptativa baseada na média local
    """
    # TODO: Implementar limiarização adaptativa
    # Dica: use np.pad e np.mean na vizinhança de cada pixel
    pass

# Exemplo de uso:
# mask = adaptive_threshold(img_gray, block_size=35, c=10)
# plt.imshow(mask, cmap='gray')
# plt.title('Limiarização Adaptativa')
# plt.axis('off')
# plt.show()

# %% [markdown]
# ### Exercício 1.3: Limiarização de Otsu
#
# Use Otsu para encontrar automaticamente o melhor limiar e compare com a limiarização global.
#
# **Tarefa:** Aplique `filters.threshold_otsu` em `img_gray` e exiba a máscara resultante.

# %%
# TODO: Calcular limiar de Otsu e criar máscara binária
# thresh = filters.threshold_otsu(img_gray)
# otsu_mask = img_gray > thresh
# plt.imshow(otsu_mask, cmap='gray')
# plt.title(f'Otsu Threshold = {thresh}')
# plt.axis('off')
# plt.show()

# %% [markdown]
# ### Exercício 1.4: Limiarização em Imagem Colorida
#
# Aplique limiarização em um canal de cor, como o canal V do espaço HSV.
#
# **Tarefa:** Converta `img_color` para HSV e crie uma máscara usando um limiar no canal de brilho.

# %%
# TODO: Converta a imagem para HSV e aplique limiar no canal de brilho
# img_hsv = color.rgb2hsv(img_color)
# v_channel = img_hsv[:, :, 2]
# mask = v_channel > 0.5
# plt.imshow(mask, cmap='gray')
# plt.title('Limiarização no Canal V')
# plt.axis('off')
# plt.show()

# %% [markdown]
# ## Parte 2: Segmentação
#
# ### Exercício 2.1: Segmentação por Watershed
#
# Implemente uma segmentação de watershed a partir de marcadores simples.
#
# **Tarefa:** Use `filters.sobel` para gerar um mapa de gradiente e `morphology.watershed` para segmentar a imagem.

# %%
# TODO: Implementar watershed com gradiente e marcadores
# gradient = filters.sobel(img_gray)
# markers = np.zeros_like(img_gray)
# markers[img_gray < 50] = 1
# markers[img_gray > 150] = 2
# labels = morphology.watershed(gradient, markers)
# plt.imshow(color.label2rgb(labels, image=img_gray, bg_label=0))
# plt.title('Segmentação por Watershed')
# plt.axis('off')
# plt.show()

# %% [markdown]
# ## Parte 3: Comparação e Análise
#
# ### Exercício 3.1: Comparar diferentes métodos de limiarização
#
# Mostre lado a lado o resultado de limiarização global, adaptativa e Otsu.
#
# **Tarefa:** Crie um único gráfico comparativo.

# %%
# TODO: Comparar global_threshold, adaptive_threshold e Otsu
# fig, axes = plt.subplots(1, 3, figsize=(15, 5))
# axes[0].imshow(global_threshold(img_gray, 128), cmap='gray')
# axes[0].set_title('Global')
# axes[1].imshow(adaptive_threshold(img_gray, 35, 10), cmap='gray')
# axes[1].set_title('Adaptativa')
# axes[2].imshow(img_gray > filters.threshold_otsu(img_gray), cmap='gray')
# axes[2].set_title('Otsu')
# for ax in axes: ax.axis('off')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### Exercício 3.2: Comparação de segmentação de cor e região
#
# Compare a segmentação K-means com watershed em `img_color` ou `img_gray`.
#
# **Tarefa:** Exiba os resultados lado a lado e discuta as diferenças.

# %%
# TODO: Exibir resultado de K-means e watershed lado a lado
# fig, axes = plt.subplots(1, 2, figsize=(14, 6))
# axes[0].imshow(segmented)
# axes[0].set_title('K-means')
# axes[1].imshow(color.label2rgb(labels, image=img_gray, bg_label=0))
# axes[1].set_title('Watershed')
# for ax in axes: ax.axis('off')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Conclusão
#
# Neste notebook, você aplicou várias técnicas de limiarização e segmentação. Experimente diferentes parâmetros, imagens e pré-processamentos para ver como cada método se comporta.
#
# **Próximos passos:**
# - Teste limiarização adaptativa com pesos gaussianos
# - Explore o algoritmo de segmentação de SLIC
# - Aplique segmentação em imagens médicas ou de satélite
